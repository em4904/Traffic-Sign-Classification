# %%
pip install --pre scikit-learn opencv-contrib-python joblib matplotlib gradio pandas
# Out:
# Requirement already satisfied: scikit-learn in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: joblib in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: gradio in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (5.49.1)
# Requirement already satisfied: pandas in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.115.13)
# Requirement already satisfied: ffmpy in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.34.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (3.11.4)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.14.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (4.14.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.34.3)
# Requirement already satisfied: fsspec in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.7.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: idna>=2.8 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.1.0)
# Requirement already satisfied: colorama in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\esha\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.5.0)
# Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl (45.3 MB)
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/45.3 MB 22.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.3/45.3 MB 16.8 MB/s eta 0:00:03
#    ------- -------------------------------- 8.9/45.3 MB 15.4 MB/s eta 0:00:03
#    --------- ------------------------------ 10.5/45.3 MB 13.2 MB/s eta 0:00:03
#    ------------ --------------------------- 14.4/45.3 MB 14.5 MB/s eta 0:00:03
#    --------------- ------------------------ 17.3/45.3 MB 14.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 19.9/45.3 MB 14.1 MB/s eta 0:00:02
#    -------------------- ------------------- 22.8/45.3 MB 14.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.4/45.3 MB 13.8 MB/s eta 0:00:02
#    ------------------------- -------------- 28.3/45.3 MB 13.8 MB/s eta 0:00:02
#    --------------------------- ------------ 31.2/45.3 MB 13.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.8/45.3 MB 13.7 MB/s eta 0:00:01
#    -------------------------------- ------- 36.4/45.3 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.3/45.3 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/45.3 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  44.8/45.3 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 45.3/45.3 MB 13.1 MB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\ESHA\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.cluster import MiniBatchKMeans
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import joblib
import matplotlib.pyplot as plt

# Path to your dataset
TRAIN_PATH = r"traffic_Data/DATA"
TEST_PATH  = r"traffic_Data/TEST"
LABELS_CSV = r"labels.csv"

VOCAB_SIZE = 200
MAX_SIFT_PER_IMAGE = 400
RANDOM_STATE = 42

print("✅ Imports OK")
# Out:
# ✅ Imports OK

# %%
labels_df = pd.read_csv(LABELS_CSV)
class_names = labels_df.set_index("ClassId")["Name"].to_dict()

num_classes = len(class_names)
print(f"✅ Found {num_classes} classes")
print(class_names)
# Out:
# ✅ Found 58 classes
# {0: 'Speed limit (5km/h)', 1: 'Speed limit (15km/h)', 2: 'Speed limit (30km/h)', 3: 'Speed limit (40km/h)', 4: 'Speed limit (50km/h)', 5: 'Speed limit (60km/h)', 6: 'Speed limit (70km/h)', 7: 'speed limit (80km/h)', 8: 'Dont Go straight or left', 9: 'Dont Go straight or Right', 10: 'Dont Go straight', 11: 'Dont Go Left', 12: 'Dont Go Left or Right', 13: 'Dont Go Right', 14: 'Dont overtake from Left', 15: 'No Uturn', 16: 'No Car', 17: 'No horn', 18: 'Speed limit (40km/h)', 19: 'Speed limit (50km/h)', 20: 'Go straight or right', 21: 'Go straight', 22: 'Go Left', 23: 'Go Left or right', 24: 'Go Right', 25: 'keep Left', 26: 'keep Right', 27: 'Roundabout mandatory', 28: 'watch out for cars', 29: 'Horn', 30: 'Bicycles crossing', 31: 'Uturn', 32: 'Road Divider', 33: 'Traffic signals', 34: 'Danger Ahead', 35: 'Zebra Crossing', 36: 'Bicycles crossing', 37: 'Children crossing', 38: 'Dangerous curve to the left', 39: 'Dangerous curve to the right', 40: 'Unknown1', 41: 'Unknown2', 42: 'Unknown3', 43: 'Go right or straight', 44: 'Go left or straight', 45: 'Unknown4', 46: 'ZigZag Curve', 47: 'Train Crossing', 48: 'Under Construction', 49: 'Unknown5', 50: 'Fences', 51: 'Heavy Vehicle Accidents', 52: 'Unknown6', 53: 'Give Way', 54: 'No stopping', 55: 'No entry', 56: 'Unknown7', 57: 'Unknown8'}

# %%
def load_train_images(path):
    images = []
    labels = []
    for class_id in sorted(os.listdir(path), key=lambda x: int(x)):
        class_folder = os.path.join(path, class_id)
        if not os.path.isdir(class_folder):
            continue
        for fname in os.listdir(class_folder):
            fpath = os.path.join(class_folder, fname)
            img = cv2.imread(fpath)
            if img is None:
                continue
            images.append((fpath, img))
            labels.append(int(class_id))
    return images, np.array(labels)

def load_test_images(path):
    images = []
    for fname in os.listdir(path):
        fpath = os.path.join(path, fname)
        img = cv2.imread(fpath)
        if img is None:
            continue
        images.append((fpath, img))
    return images

train_images, train_labels = load_train_images(TRAIN_PATH)
test_images  = load_test_images(TEST_PATH)

print("✅ Training images:", len(train_images))
print("✅ Test images:", len(test_images))
# Out:
# ✅ Training images: 4170
# ✅ Test images: 1994

# %%
sift = cv2.SIFT_create()

all_desc = []
image_descs = []
missing = 0

for path, img in train_images:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kps, des = sift.detectAndCompute(gray, None)

    if des is None:
        image_descs.append(None)
        missing += 1
        continue

    if len(des) > MAX_SIFT_PER_IMAGE:
        des = des[:MAX_SIFT_PER_IMAGE]

    image_descs.append(des)
    all_desc.append(des)

stacked = np.vstack(all_desc)
print("✅ Total descriptors for clustering:", stacked.shape)
print("❗ Images without descriptors:", missing)
# Out:
# ✅ Total descriptors for clustering: (466044, 128)
# ❗ Images without descriptors: 14

# %%
print("⏳ Building BoVW vocabulary...")

kmeans = MiniBatchKMeans(
    n_clusters=VOCAB_SIZE,
    batch_size=VOCAB_SIZE * 20,
    random_state=RANDOM_STATE
)

kmeans.fit(stacked)
joblib.dump(kmeans, "bovw_kmeans.joblib")

print("✅ Saved vocabulary → bovw_kmeans.joblib")
# Out:
# ⏳ Building BoVW vocabulary...
# ✅ Saved vocabulary → bovw_kmeans.joblib

# %%
def descriptors_to_bovw(des, kmeans_model, vocab_size):
    hist = np.zeros(vocab_size, dtype=np.float32)
    if des is None:
        return hist
    idxs = kmeans_model.predict(des)
    for i in idxs:
        hist[i] += 1
    if hist.sum() > 0:
        hist /= hist.sum()
    return hist

bovw = np.array([descriptors_to_bovw(d, kmeans, VOCAB_SIZE) for d in image_descs])
print("✅ BoVW feature matrix:", bovw.shape)
# Out:
# ✅ BoVW feature matrix: (4170, 200)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    bovw, train_labels,
    test_size=0.2,
    stratify=train_labels,
    random_state=RANDOM_STATE
)

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_val_s   = scaler.transform(X_val)

joblib.dump(scaler, "bovw_scaler.joblib")

print("✅ Train:", X_train_s.shape)
print("✅ Val:",   X_val_s.shape)
# Out:
# ✅ Train: (3336, 200)
# ✅ Val: (834, 200)

# %%
print("⏳ Training SVM ...")

svm = LinearSVC(random_state=RANDOM_STATE, max_iter=20000)
svm.fit(X_train_s, y_train)
joblib.dump(svm, "sift_bovw_svm.joblib")

print("✅ SVM saved → sift_bovw_svm.joblib")

y_pred = svm.predict(X_val_s)
print("✅ Validation accuracy:", accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# ⏳ Training SVM ...
# ✅ SVM saved → sift_bovw_svm.joblib
# ✅ Validation accuracy: 0.9448441247002398
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        24
#            1       1.00      1.00      1.00         8
#            2       0.89      1.00      0.94        16
#            3       1.00      1.00      1.00        52
#            4       1.00      0.90      0.95        20
#            5       0.95      0.90      0.92        39
#            6       0.89      1.00      0.94        16
#            7       1.00      1.00      1.00        30
#            8       1.00      1.00      1.00         2
#           10       0.88      1.00      0.93        14
#           11       0.93      0.93      0.93        28
#           12       1.00      1.00      1.00        19
#           13       1.00      1.00      1.00         7
#           14       1.00      0.85      0.92        26
#           15       1.00      1.00      1.00         4
#           16       0.93      0.93      0.93        28
#           17       0.92      0.92      0.92        26
#           18       0.00      0.00      0.00         2
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         4
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         4
#           23       1.00      1.00      1.00         3
#           24       0.91      1.00      0.95        20
#           26       0.92      0.92      0.92        25
#           27       1.00      1.00      1.00         6
#           28       1.00      1.00      1.00        89
#           29       0.82      1.00      0.90         9
#           30       0.88      1.00      0.94        30
#           31       1.00      1.00      1.00         8
#           32       1.00      1.00      1.00         3
#           33       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         5
#           35       0.93      0.87      0.90        31
#           36       1.00      1.00      1.00         8
#           37       1.00      1.00      1.00        12
#           38       1.00      1.00      1.00         6
#           39       1.00      1.00      1.00         7
#           40       0.67      0.67      0.67         6
#           41       1.00      1.00      1.00         4
#           42       1.00      1.00      1.00         6
#           43       0.89      1.00      0.94        16
#           44       0.83      0.83      0.83         6
#           45       1.00      1.00      1.00         5
#           46       1.00      0.50      0.67         4
#           47       1.00      1.00      1.00         2
#           48       1.00      1.00      1.00         2
#           49       1.00      0.75      0.86         8
#           50       1.00      1.00      1.00        11
#           51       1.00      1.00      1.00         2
#           52       1.00      1.00      1.00         7
#           54       0.82      0.92      0.87        65
#           55       1.00      0.81      0.90        32
#           56       0.91      0.91      0.91        22
#           57       1.00      1.00      1.00         1
#
#     accuracy                           0.94       834
#    macro avg       0.94      0.94      0.94       834
# weighted avg       0.95      0.94      0.94       834
# c:\Users\ESHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ESHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ESHA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
def predict_image_sift_bovw(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    kps, des = sift.detectAndCompute(gray, None)

    hist = descriptors_to_bovw(des, kmeans, VOCAB_SIZE).reshape(1, -1)
    hist_s = scaler.transform(hist)

    pid = svm.predict(hist_s)[0]
    name = class_names.get(pid, "Unknown")

    return pid, name

# %%
if len(test_images) > 0:
    path, img = test_images[0]
    pid, name = predict_image_sift_bovw(img)
    print("✅ Example prediction:", name)
# Out:
# ✅ Example prediction: Speed limit (30km/h)

# %%
import gradio as gr

def gradio_predict(pil_img):
    img = np.array(pil_img)[:, :, ::-1]  # RGB → BGR
    pid, name = predict_image_sift_bovw(img)
    return name

ui = gr.Interface(
    fn=gradio_predict,
    inputs=gr.Image(type="pil", label="Upload Traffic Sign"),
    outputs=gr.Textbox(label="Predicted Class"),
    title="SIFT + BoVW + SVM Traffic Sign Classifier",
    description="Upload an image to classify it."
)

# Uncomment to run:
# ui.launch(share=True)

# %%
ui.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://91acc1e36c12b5b09b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://91acc1e36c12b5b09b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
